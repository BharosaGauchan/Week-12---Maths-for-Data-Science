# %% [markdown]
# ### 1. Calculating Probabilities using Bayes’ Theorem
#
# A computer graphics card is manufactured using three different processes, A, B, and C. The following
# tree diagram gives the probability that a graphics card is manufactured with each process and the
# probability of defective and non-defective cards from each process.

# %%
#(a) If a randomly chosen graphics card is defective, what is the probability it was manufactured using Process A?
A = 0.5 # P(A)
AD =.03 # P(B/A)
D = (0.5*.03)+(0.3*.02)+(0.2*.04) # P(B)
bayes = ((A * AD)/D)*100 # Bayes Theorem
print('The probability of randomly chosen graphic is defecteve using process A is:','{:.2f}%'.format(bayes))
# Out:
# The probability of randomly chosen graphic is defecteve using process A is: 51.72%

# %%
#(b) If a randomly chosen graphics card is not defective, what is the probability it was manufacture using Process C?
C = 0.2 # P(A)
NDC = .96 #P(B/A)
ND = (0.5*0.97)+(0.3*.98)+(0.2*.96) # P(B)
bayes = ((C * NDC)/ND)*100 # Bayes Theorem 
print('The probability of randomly chosen graphic is notdefecteve using process C is:','{:.2f}%'.format(bayes))
# Out:
# The probability of randomly chosen graphic is notdefecteve using process C is: 19.77%

# %% [markdown]
# ## 2. Entropy Function for a Probability Distribution
#
# Create a Python function that takes in an array of probabilities p1, p2, . . . , pn, from a discrete probability distribution with n possible outcomes and returns the entropy of the corresponding random
# variable. Use the formula on p. 143 of Essential Math for Data Science to calculate the entropy

# %%
def entropy(P):
    return - np.sum(P * np.log2(P))

# %% [markdown]
# ## Calculating Entropies of Probability Distributions

# %%
# a) Use the function you created in the previous problem to calculate the entropies of X and Y
import numpy as np
X = np.array([.2,.2,.2,.2,.2])
Y = np.array([.1,.4,.1,.3,.1])
a = '{:.4f}'.format(entropy(X))
b = '{:.4f}'.format(entropy(Y))
print('The entropies of X is :',a,'\n The entropies of Y is :', b)
# Out:
# The entropies of X is : 2.3219
#  The entropies of Y is : 2.0464

# %% [markdown]
# (b) Compare the two values found in part (a). Which one is bigger? Explain intuitively why this is the case.
#
# The entropies of X is bigger than entropies of Y. Higher entropy is equal to more uncertain. Since the all the value of X is same, uncertainity of the posible outcome is higher value while different values of Y makes the results less surprise.
